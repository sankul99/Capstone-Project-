# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans

# %%
df_crimes = pd.read_csv(r'C:\Users\sanku\OneDrive\Desktop\India_Crime - Copy\India_Crime - Copy\01_District_wise_crimes_committed_IPC_2001_2012.csv')

# %%
df_crimes.head()
# Out:
#          STATE/UT       DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0  ANDHRA PRADESH       ADILABAD  2001     101                 60
# 1  ANDHRA PRADESH      ANANTAPUR  2001     151                125
# 2  ANDHRA PRADESH       CHITTOOR  2001     101                 57
# 3  ANDHRA PRADESH       CUDDAPAH  2001      80                 53
# 4  ANDHRA PRADESH  EAST GODAVARI  2001      82                 67
#
#    CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 0                                         17    50               0
# 1                                          1    23               0
# 2                                          2    27               0
# 3                                          1    20               0
# 4                                          1    23               0
#
#    OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 0          50                      46  ...     30                1131
# ...

# %%
main_df = df_crimes[['STATE/UT', 'DISTRICT', 'YEAR',  'TOTAL IPC CRIMES']]

# %%
main_df.head()
# Out:
#          STATE/UT       DISTRICT  YEAR  TOTAL IPC CRIMES
# 0  ANDHRA PRADESH       ADILABAD  2001              4154
# 1  ANDHRA PRADESH      ANANTAPUR  2001              4125
# 2  ANDHRA PRADESH       CHITTOOR  2001              5818
# 3  ANDHRA PRADESH       CUDDAPAH  2001              3140
# 4  ANDHRA PRADESH  EAST GODAVARI  2001              6507

# %%
new_df = df_crimes.iloc[:,3:]

# %%
new_df.head()
# Out:
#    MURDER  ATTEMPT TO MURDER  CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  \
# 0     101                 60                                         17    50
# 1     151                125                                          1    23
# 2     101                 57                                          2    27
# 3      80                 53                                          1    20
# 4      82                 67                                          1    23
#
#    CUSTODIAL RAPE  OTHER RAPE  KIDNAPPING & ABDUCTION  \
# 0               0          50                      46
# 1               0          23                      53
# 2               0          27                      59
# 3               0          20                      25
# 4               0          23                      49
#
#    KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS  \
# 0                                           30
# 1                                           30
# ...

# %%
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(new_df)

# %%
kmeans = KMeans(n_clusters=3, init='k-means++')
kmeans.fit(data_scaled)
# Out:
# C:\Users\sanku\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=3)

# %%
df_crimes['cluster'] = kmeans.labels_

# %%
peaceful_areas = df_crimes[df_crimes['cluster'] == 0]
sensitive_areas = df_crimes[df_crimes['cluster'] == 1]
moderate_areas = df_crimes[df_crimes['cluster'] == 2]

# %%
sensitive_areas
# Out:
#           STATE/UT        DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 70           ASSAM           TOTAL  2001    1356                481
# 115          BIHAR           TOTAL  2001    3643               3419
# 135   CHHATTISGARH           TOTAL  2001     880                529
# 169        GUJARAT           TOTAL  2001    1226                537
# 253      JHARKHAND           TOTAL  2001    1507                866
# ...            ...             ...   ...     ...                ...
# 8500     JHARKHAND           TOTAL  2012    1694                842
# 8536     KARNATAKA           TOTAL  2012    1860               1923
# 8557        KERALA           TOTAL  2012     374                497
# 8734        ODISHA           TOTAL  2012    1548               1879
# 8997      DELHI UT  DELHI UT TOTAL  2012     521                439
#
#       CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 70                                           40   817               0
# ...

# %%
peaceful_areas
# Out:
#             STATE/UT       DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0     ANDHRA PRADESH       ADILABAD  2001     101                 60
# 1     ANDHRA PRADESH      ANANTAPUR  2001     151                125
# 2     ANDHRA PRADESH       CHITTOOR  2001     101                 57
# 3     ANDHRA PRADESH       CUDDAPAH  2001      80                 53
# 4     ANDHRA PRADESH  EAST GODAVARI  2001      82                 67
# ...              ...            ...   ...     ...                ...
# 9012     LAKSHADWEEP    LAKSHADWEEP  2012       0                  0
# 9013     LAKSHADWEEP          TOTAL  2012       0                  0
# 9014      PUDUCHERRY       KARAIKAL  2012       5                  6
# 9015      PUDUCHERRY     PUDUCHERRY  2012      24                 21
# 9016      PUDUCHERRY          TOTAL  2012      29                 27
#
#       CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# ...

# %%
moderate_areas
# Out:
#             STATE/UT DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 28    ANDHRA PRADESH    TOTAL  2001    2602               1555
# 351   MADHYA PRADESH    TOTAL  2001    2425               2870
# 397      MAHARASHTRA    TOTAL  2001    2839               1454
# 529        RAJASTHAN    TOTAL  2001    1259               1923
# 650    UTTAR PRADESH    TOTAL  2001    7601               7964
# ...              ...      ...   ...     ...                ...
# 8657     MAHARASHTRA    TOTAL  2012    2712               2168
# 8806       RAJASTHAN    TOTAL  2012    1461               1538
# 8851      TAMIL NADU    TOTAL  2012    1949               2954
# 8938   UTTAR PRADESH    TOTAL  2012    4966               4811
# 8982     WEST BENGAL    TOTAL  2012    2252               2854
#
#       CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 28                                          136   871               0
# ...
